# %%
# plot mediapipe z value

# %%
## Import libraries 
import matplotlib.pyplot as plt 
import pandas as pd 
import os

# %%
# set input file and output folder - individidually for now, make loop later 

#adjust input_file and output_folder below 
input_file_full = 'MM_HC_17ft_walk_mediapipe.csv'
output_folder = r'..\..\temp\main_branch_outputs\002_visualize_run\MM_HC\z'
print('output_folder: ' + output_folder)

#keep these constant 
input_folder = r'..\..\temp\main_branch_outputs\000_run'
print('input_folder: ' + input_folder)

#merge input folder and file -> input filepath 
input_file_path = os.path.normpath(os.path.join(input_folder, input_file_full))
print('input_file_path: ' + input_file_path)

# read .csv and print first five columns
df_mp = pd.read_csv(input_file_path)
# Out:
# output_folder: ..\..\temp\main_branch_outputs\002_visualize_run\MM_HC\z
# input_folder: ..\..\temp\main_branch_outputs\000_run
# input_file_path: ..\..\temp\main_branch_outputs\000_run\MM_HC_17ft_walk_mediapipe.csv

# %%
df_mp.head()
df_rhip = df_mp.loc[df_mp['label'] == 'right_hip']
df_rhip.head()
# Out:
#      Unnamed: 0         X         Y         Z       vis  pres  frame  \
# 24           24  0.637925  0.480678  0.040413  0.999676   0.0      0
# 57           24  0.665872  0.486214  0.106440  0.999647   0.0      1
# 90           24  0.671273  0.488590  0.100415  0.999636   0.0      2
# 123          24  0.678740  0.489419  0.100245  0.999638   0.0      3
# 156          24  0.684196  0.489332  0.091349  0.999642   0.0      4
#
#          label
# 24   right_hip
# 57   right_hip
# 90   right_hip
# 123  right_hip
# 156  right_hip

# %%
plt.plot(df_rhip['frame'], df_rhip['Z'])
plt.xlabel('Frame')
plt.ylabel('R Hip Z (Relative to Hip Origin)')
plt.title(input_file_full)
plt.savefig(os.path.normpath(os.path.join(output_folder, 'MM_HC_17ft_walk_mediapipe.png')))
